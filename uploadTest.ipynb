# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/zs/zssr
# Out:
# /gdrive/MyDrive/zs/zssr

# %%
# !echo "# 2021-1-Classification_4classes" >> README.md
# !git init
# !git config --global user.email "ehdgk1331@naver.com"
# !git config --global user.name "Dongpaca"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://Dongpaca:12!sdasda@github.com/Dongpaca/ZSSR.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /gdrive/My Drive/zs/zssr/.git/
# [main 067c870] first commit
#  1 file changed, 1 insertion(+)
# To https://github.com/Dongpaca/ZSSR.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://Dongpaca:12!sdasda@github.com/Dongpaca/ZSSR.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://Dongpaca:12!sdasda@github.com/Dongpaca/ZSSR.git'

# %%
# !git remote rm origin
# Out:
# fatal: No such remote: origin

# %%
# !git init

# !git add .

# !git commit -m "message"
# Out:
# Reinitialized existing Git repository in /gdrive/My Drive/zs/zssr/.git/
# [main c9d6196] message
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite uploadTest.ipynb (100%)
